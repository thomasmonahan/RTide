       1.60006625e-03, 1.42035014e-03, 1.25888117e-03, 1.21582618e-03,
       1.15983346e-03, 1.13589867e-03, 7.27191018e-04, 5.66714794e-04,
       4.59664834e-04, 4.42728050e-04, 3.61904833e-04]

phases = [100.17759146,  67.89243773, 139.00250991, 137.86574464,
       200.97272826,  74.79464737, 165.69341288, 153.88678437,
        58.36570311,  89.0912145 , 127.98741436, 191.68500006,
       278.47737423, 244.0325824 , 177.04405382,  44.34332198,
        52.25904325, 323.89847841, 133.57991772, 136.30167208,
        28.30723094, 217.33413263, 126.53992866, 161.0469261 ,
       174.82541658,  15.58408105,   7.47832655,  31.42622825,
        97.44531604,  99.02486302,  68.17868939, 330.05943051,
       150.29924914, 251.95764691, 210.86869631,   7.60600294,
       230.66692903,  69.11247392, 271.44019503,  86.11567323,
       339.08199382, 158.8889673 ,  35.15053441, 133.53233952,
       257.70571862,   5.82066898, 106.55105815,  20.09288806,
         6.71678559, 332.8022366 ,  84.89100071,  26.87074928,
       195.77759826, 285.62386608, 303.69083469, 319.58250059,
        45.59421571,   9.39030707, 156.23344292]

# %% [markdown]
# ## Generating A Synthetic Tidal Signal:

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
### Producing a 1-year reference series sampled at 6' intervals
times = pd.date_range(start = '2024-01-01 00:00:00+00:00', periods=24*365, freq="1h",tz='UTC')
time_vals = times.to_julian_date().to_numpy()

### Computing the contribution of each constituent
individual_tides = []
for i,j in enumerate(constit_freqs):
    individual_tides.append(amplitudes[i]*np.cos(24*j*np.array(time_vals) * 2 * np.pi + (phases[i] *np.pi /180)))

### Calculating the final tide as the superposition of all constituents for each time instance
tide = np.sum(individual_tides, axis = 0) + 0.1*np.random.normal(len(individual_tides))

# %%
### We have a tidal signal!
plt.plot(times, tide)
plt.xlim(times[0], times[-1])
plt.title('Synthetic tide')
plt.xlabel('Time')
plt.ylabel('Sea Level (m)')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %% [markdown]
# ## Simple Application of RTide
#
# RTide can be run using three lines of code. By default, RTide takes pandas dataframes with date-time indexes as input and measurements provided in a column labeled 'observations'. It is best practice to use frequency aware indexes.
#
# In addition to the observations dataframe, RTide also requires the latitude, longitude.
#
# To remove the need to recompute the global tide function in between runs, a file name should be specified to save the computed input functions, inputs, and trained model. An Rtide saves folder will automatically be added to the directory to prevent excess clutter.

# %%
import rtide
from rtide import RTide

# %%
df = pd.DataFrame({'observations':tide}, index = times)

# %%
model = RTide(df[:7000], lat = 44.9062, lon = -66.996201)

inputs = {
          'symmetrical': True,
          'path': 'basic_synthetic',
}
model.Prepare_Inputs(**inputs)

# %%
train_inputs = {
    'loss' : 'MSE',
    'save_weights' : True,
    'lr':1e-3,
    'standard_epochs': 500,
    'early_stoppage':30,
    'regularization_strength':0.001
}
model.Train(**train_inputs)
# Out:
# #### Model Overview ####
# Mode: elevation
# Outputs: ['observations']
# Learning Rate: 0.001
# Loss: MSE
# Standard Epochs: 500
# Regularization: 0.001
# Number of Layers: 3
# Has Exogenous Inputs (multi): False
# Save Weights: True
# Epoch 1/500
# /opt/anaconda3/envs/rtide_testing/lib/python3.11/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
#
# 186/186 - 0s - 925us/step - loss: 0.0114 - val_loss: 0.0116 - learning_rate: 1.0000e-04
# Epoch 189/500
# 186/186 - 0s - 1ms/step - loss: 0.0113 - val_loss: 0.0114 - learning_rate: 1.0000e-04
# Epoch 190/500
# 186/186 - 0s - 934us/step - loss: 0.0113 - val_loss: 0.0114 - learning_rate: 1.0000e-04
# Epoch 191/500
# 186/186 - 0s - 927us/step - loss: 0.0113 - val_loss: 0.0111 - learning_rate: 1.0000e-04
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step
# /opt/anaconda3/envs/rtide_testing/lib/python3.11/site-packages/utide/_time_conversion.py:26: UserWarning: no explicit representation of timezones available for np.datetime64
#   date = date.astype("datetime64[ms]")

# %% [markdown]
# ### Let's look at the train results:
#
# Unsurprisingly, when dealing with a purely harmonic signal HA is going to be hard to beat...
# This exposes a crucial distinction between these methods. Because RTide is not composed of harmonics it can only get $\epsilon$ close to a truly harmonic function. However, this same characteristic enables RTide to use less data and more efficiently be applied to non-stationary data. Equivalent harmonic predictions are also simultaneously computed and included in the results.

# %%
model.Visualize_Residuals(tides = True)

# %%
model.Visualize_Predictions()
# Out:
# Train Results
# r2: 0.9961712772864779 MSE: 0.01522536788743488 MAE : 0.09887504523475897 MAPE : 0.018368862697538565

# %% [markdown]
# ### Now let's generate some out of sample predictions and look at the results:
#
# Note that the visualize residuals/predictions functions will automatically plot whatever data is available. e.g. if you only generate predictions from a pre-trained model it will only show predictions.

# %%
model.Predict(df[7000:])
# Out:
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 452us/step
# /opt/anaconda3/envs/rtide_testing/lib/python3.11/site-packages/utide/_time_conversion.py:26: UserWarning: no explicit representation of timezones available for np.datetime64
#   date = date.astype("datetime64[ms]")

# %%
model.Visualize_Residuals(tides = False)

# %%
model.Visualize_Residuals(tides = True)

# %%
model.Visualize_Predictions()
# Out:
# Train Results
# r2: 0.9961712772864779 MSE: 0.01522536788743488 MAE : 0.09887504523475897 MAPE : 0.018368862697538565
# Test Results
# r2: 0.9868334640805928 MSE: 0.05174418204567516 MAE : 0.18430404483916132 MAPE : 0.03423133881972126

# %% [markdown]
# ### Non-tidal Forcing
#
# Far more interesting than a pure tidal signal is one contaminated by non-tidal forcing. Here, we show how RTide can be employed to efficiently study these effects and generate predictions. In particular we look at a signal contaminated by an external surge, and want to predict both the true tidal signal and the nonlinear tide-surge response. A simple approximation for this behavior is given by:
#
#
# $\zeta(t) = \zeta_T + \zeta_S + A\times\zeta_S(\zeta_T ' + \zeta_T '')$

# %% [markdown]
# #### Create Surge Signal

# %%
def add_white_noise(signal, snr_dB):
    """
    Helper function to add white gaussian noise at specified snr_dB.
    """
    # Extract the portion of the signal to add noise to
    original_signal = signal

    # Calculate the power of the original signal
    original_power = np.mean(original_signal**2)

    # Calculate the noise power based on the desired SNR (in linear scale)
    snr_linear = 10**(snr_dB / 10.0)
    noise_power = original_power / snr_linear

    # Generate white noise with the same length as the original signal
    noise = np.random.normal(0, np.sqrt(noise_power), len(original_signal))

    # Add the noise to the original signal
    noisy_signal = original_signal + noise

    return noisy_signal

import random

def random_indices_within_chunks(lst, x, l):
    """
    Randomly select indices within chunks of a list, excluding l indices from both ends.

    Parameters:
    - lst: The input list.
    - x: The length of each chunk.
    - l: The number of excluded indices from both ends of each chunk.

    Returns:
    - A list of randomly selected indices.
    """
    indices = []
    chunk_start = 0
    seed_val = 0
    while chunk_start < len(lst):
        chunk_end = min(chunk_start + x, len(lst))
        valid_indices = list(range(chunk_start + l, chunk_end - l))

        if valid_indices:
            random.seed(seed_val)
            random_index = random.choice(valid_indices)
            indices.append(random_index)
            seed_val+=1
        chunk_start = chunk_end

    return indices
## Tide
times = pd.date_range(start = '2024-01-01 00:00:00+00:00', periods=24*365, freq="1h",tz='UTC')
time_vals = times.to_julian_date().to_numpy()

### Computing the contribution of each constituent
individual_tides = []
for i,j in enumerate(constit_freqs):
    individual_tides.append(amplitudes[i]*np.cos(24*j*np.array(time_vals) * 2 * np.pi + (phases[i] *np.pi /180)))

tide = np.sum(individual_tides, axis = 0)
## Surges
surge_min = 0.1
surge_max = 1
surge_duration_min = 0.25
surge_duration_max = 4

np.random.seed(45) ### Using same seed for consistency
surge_duration = [np.random.uniform(surge_duration_min,surge_duration_max) for i in range(26)]
np.random.seed(46) ### Using same seed for consistency
surge_intensity= [np.random.uniform(surge_min,surge_max) for i in range(26)]

surges = [surge_intensity[i]*(1 - np.cos(24*2*np.pi*np.arange(0,surge_duration[i], 0.041666666666666664)/(surge_duration[i]*24))) for i in range(len(surge_duration))]

### Tide-Surge Function
first_derivative = np.gradient(tide)
second_derivative = np.gradient(np.gradient(tide))
indices = np.where((first_derivative > 0) & (second_derivative > 0))[0]
mults = np.zeros(len(tide))
mults[indices] = 1
window_size = 4
smooth_mults = 0.33*(first_derivative+ second_derivative)
smooth_mults_test = np.zeros(len(tide))

random_indices = random_indices_within_chunks(tide, 14*24, 96)

mod_tide = tide.copy()
for i,surge in enumerate(surges):
  for xval in range(len(surge)):
    mod_tide[xval+random_indices[i]] += surge[xval]
    smooth_mults_test[xval+random_indices[i]] = smooth_mults[xval + random_indices[i]] * surge[xval]

observations = mod_tide + smooth_mults_test ## Tide + Surge + tide-surge
surge = mod_tide - tide

observations = add_white_noise(observations, 100)

surge_df = pd.DataFrame({'observations': observations, 'surge': surge}, index = times)

# %% [markdown]
# #### Plotting

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming df, df2, and tide are defined somewhere in your code
# First subplot
fig = plt.figure(figsize=(18, 6))  # Adjust the width and height as needed

plt.subplot(1, 2, 1)

plt.plot(surge_df.index, surge_df.observations, label = 'observations', color = 'black')
plt.plot(surge_df.index, smooth_mults_test, label = 'tide-surge', color = 'green')
plt.plot(surge_df.index, surge_df.surge, label = 'surge', color = 'red')
plt.ylabel('Sea Level (m)')
plt.xlabel('Time')
plt.xlim(surge_df.index[0], surge_df.index[-1])
plt.title("Synthetic Tide + Surge Signal")

# Second subplot
plt.subplot(1, 2, 2)
plt.plot(tide[:72 ], label='Tide', color='k')
surge2 = (1 - np.cos(24 * 2 * np.pi * np.arange(0, 3, 0.041666666666666664) / (72)))
plt.plot(surge2, label='Surge', color='red')
surge3 = (1 - np.cos(24 * 2 * np.pi * np.arange(0, 365, 0.041666666666666664) / (72)))
window_size = 7
smooth_mults2 = np.convolve(mults, np.ones(window_size) / window_size, mode='same')
# Adjust the range of smoothed values to be between 0 and 1
smooth_vals = smooth_mults2 + 0.1
first_derivative1 = np.gradient(tide)
second_derivative1 = np.gradient(np.gradient(tide))
plt.plot(surge3[:72 ] * 0.33 * (first_derivative1 + second_derivative1)[:72 ],
         label='Tide-Surge Interaction', color='green')
total = tide[:72 ] + surge3[:72 ] + surge3[:72 ] * 0.33 * (first_derivative1 + second_derivative1)[:72 ]
plt.plot(total, label='Total', color='blue')
plt.xlim(0, 72 )
plt.xticks([0,24, 48, 72], [0, 1, 2, 3])
plt.xlabel('Time (D)', fontsize = 14)

plt.legend(fontsize = 14)

# Adjust layout for better spacing
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Running Response
# Multivariate inputs are simply included as an additional column in the input dataframe. It still only takes three lines of code to build and train a model for any number of multivariate inputs!

# %%
trend = 0.1*(np.arange(len(observations))  / (0.5*len(observations)))

surge_df = pd.DataFrame({'observations': observations + trend,'surge': surge}, index = times)

model = RTide(surge_df[:8000], lat = 44.9062, lon = -66.996201)

model.Prepare_Inputs(symmetrical = True, multivariate_lags = [-3,-2,-1], path = 'simple_surge')
# Out:
# [RTide] Using cached input features from previous run.
#          CSV : ./rtide_saves/simple_surge_global_tide.csv
#          PKL : ./rtide_saves/simple_surge_inputs.pkl
#          NOTE: Cached inputs reused. Set force_recompute=True to override.

# %%
surge_inputs = {
    'regularization_strength': 0.001,
    'loss' : 'MSE',
    'save_weights' : True,
    'lr':1e-3,
    'standard_epochs': 500,
    'trend': 'linear'
}
model.Train(**surge_inputs)
# Out:
# #### Model Overview ####
# Mode: elevation
# Outputs: ['observations']
# Learning Rate: 0.001
# Loss: MSE
# Standard Epochs: 500
# Regularization: 0.001
# Number of Layers: 3
# Has Exogenous Inputs (multi): True
# Save Weights: True
# Trend Estimation: linear
# Epoch 1/500
# 213/213 - 1s - 5ms/step - loss: 1.9127 - val_loss: 0.6232 - learning_rate: 0.0010
# Epoch 2/500
# 213/213 - 0s - 951us/step - loss: 0.5675 - val_loss: 0.5380 - learning_rate: 0.0010
# Epoch 3/500
# 213/213 - 0s - 921us/step - loss: 0.5602 - val_loss: 0.6292 - learning_rate: 0.0010
# Epoch 4/500
# 213/213 - 0s - 926us/step - loss: 0.5409 - val_loss: 0.5549 - learning_rate: 0.0010
# Epoch 5/500
# 213/213 - 0s - 924us/step - loss: 0.5300 - val_loss: 0.6569 - learning_rate: 0.0010
# Epoch 6/500
# 213/213 - 0s - 919us/step - loss: 0.4931 - val_loss: 0.4711 - learning_rate: 0.0010
# Epoch 7/500
# 213/213 - 0s - 973us/step - loss: 0.4905 - val_loss: 0.4602 - learning_rate: 0.0010
# Epoch 8/500
# 213/213 - 0s - 962us/step - loss: 0.4220 - val_loss: 0.4169 - learning_rate: 0.0010
# Epoch 9/500
# 213/213 - 0s - 986us/step - loss: 0.4242 - val_loss: 0.4455 - learning_rate: 0.0010
# Epoch 10/500
# Epoch 111/500
# 213/213 - 0s - 917us/step - loss: 0.0127 - val_loss: 0.0140 - learning_rate: 1.0000e-04
# Epoch 112/500
# 213/213 - 0s - 929us/step - loss: 0.0126 - val_loss: 0.0125 - learning_rate: 1.0000e-04
# Epoch 113/500
# 213/213 - 0s - 944us/step - loss: 0.0125 - val_loss: 0.0126 - learning_rate: 1.0000e-04
# Epoch 114/500
# 213/213 - 0s - 918us/step - loss: 0.0124 - val_loss: 0.0127 - learning_rate: 1.0000e-04
# Epoch 115/500
# 213/213 - 0s - 928us/step - loss: 0.0124 - val_loss: 0.0129 - learning_rate: 1.0000e-04
# Epoch 116/500
# 213/213 - 0s - 945us/step - loss: 0.0122 - val_loss: 0.0123 - learning_rate: 1.0000e-04
# Epoch 117/500
# 213/213 - 0s - 918us/step - loss: 0.0124 - val_loss: 0.0127 - learning_rate: 1.0000e-04
# Epoch 118/500
# 213/213 - 0s - 993us/step - loss: 0.0122 - val_loss: 0.0122 - learning_rate: 1.0000e-04
# Epoch 119/500
# 213/213 - 0s - 1ms/step - loss: 0.0121 - val_loss: 0.0121 - learning_rate: 1.0000e-04
# Epoch 120/500
# 213/213 - 0s - 930us/step - loss: 0.0121 - val_loss: 0.0126 - learning_rate: 1.0000e-04
# Epoch 121/500
# 213/213 - 0s - 936us/step - loss: 0.0119 - val_loss: 0.0133 - learning_rate: 1.0000e-04
# Epoch 122/500
# 213/213 - 0s - 925us/step - loss: 0.0120 - val_loss: 0.0127 - learning_rate: 1.0000e-04
# Epoch 123/500
# 213/213 - 0s - 942us/step - loss: 0.0120 - val_loss: 0.0122 - learning_rate: 1.0000e-04
# Epoch 124/500
# 213/213 - 0s - 929us/step - loss: 0.0119 - val_loss: 0.0121 - learning_rate: 1.0000e-04
# Epoch 125/500
# 213/213 - 0s - 915us/step - loss: 0.0119 - val_loss: 0.0122 - learning_rate: 1.0000e-04
# Epoch 126/500
# 213/213 - 0s - 924us/step - loss: 0.0119 - val_loss: 0.0123 - learning_rate: 1.0000e-04
# Epoch 127/500
# 213/213 - 0s - 913us/step - loss: 0.0118 - val_loss: 0.0128 - learning_rate: 1.0000e-04
# Epoch 128/500
# 213/213 - 0s - 944us/step - loss: 0.0117 - val_loss: 0.0120 - learning_rate: 1.0000e-04
# Epoch 129/500
# 213/213 - 0s - 923us/step - loss: 0.0118 - val_loss: 0.0119 - learning_rate: 1.0000e-04
# Epoch 130/500
# 213/213 - 0s - 917us/step - loss: 0.0116 - val_loss: 0.0127 - learning_rate: 1.0000e-04
# Epoch 131/500
# 213/213 - 0s - 928us/step - loss: 0.0116 - val_loss: 0.0119 - learning_rate: 1.0000e-04
# Epoch 132/500
# 213/213 - 0s - 917us/step - loss: 0.0115 - val_loss: 0.0122 - learning_rate: 1.0000e-04
# Epoch 133/500
# 213/213 - 0s - 942us/step - loss: 0.0114 - val_loss: 0.0117 - learning_rate: 1.0000e-04
# Epoch 134/500
# 213/213 - 0s - 928us/step - loss: 0.0115 - val_loss: 0.0118 - learning_rate: 1.0000e-04
# Epoch 135/500
# 213/213 - 0s - 923us/step - loss: 0.0114 - val_loss: 0.0118 - learning_rate: 1.0000e-04
# Epoch 136/500
# 213/213 - 0s - 941us/step - loss: 0.0115 - val_loss: 0.0123 - learning_rate: 1.0000e-04
# Epoch 137/500
# 213/213 - 0s - 928us/step - loss: 0.0113 - val_loss: 0.0114 - learning_rate: 1.0000e-04
# Epoch 138/500
# 213/213 - 0s - 930us/step - loss: 0.0113 - val_loss: 0.0117 - learning_rate: 1.0000e-04
# Epoch 139/500
# 213/213 - 0s - 935us/step - loss: 0.0114 - val_loss: 0.0120 - learning_rate: 1.0000e-04
# Epoch 140/500
# 213/213 - 0s - 916us/step - loss: 0.0114 - val_loss: 0.0116 - learning_rate: 1.0000e-04
# Epoch 141/500
# 213/213 - 0s - 937us/step - loss: 0.0112 - val_loss: 0.0114 - learning_rate: 1.0000e-04
# Epoch 142/500
# 213/213 - 0s - 911us/step - loss: 0.0113 - val_loss: 0.0127 - learning_rate: 1.0000e-04
# Epoch 143/500
# 213/213 - 0s - 934us/step - loss: 0.0110 - val_loss: 0.0118 - learning_rate: 1.0000e-04
# Epoch 144/500
# 213/213 - 0s - 922us/step - loss: 0.0111 - val_loss: 0.0125 - learning_rate: 1.0000e-04
# Epoch 145/500
# 213/213 - 0s - 914us/step - loss: 0.0111 - val_loss: 0.0113 - learning_rate: 1.0000e-04
# Epoch 146/500
# 213/213 - 0s - 984us/step - loss: 0.0111 - val_loss: 0.0114 - learning_rate: 1.0000e-04
# Epoch 147/500
# 213/213 - 0s - 926us/step - loss: 0.0110 - val_loss: 0.0113 - learning_rate: 1.0000e-04
# Epoch 148/500
# 213/213 - 0s - 920us/step - loss: 0.0109 - val_loss: 0.0120 - learning_rate: 1.0000e-04
# Epoch 149/500
# 213/213 - 0s - 920us/step - loss: 0.0110 - val_loss: 0.0117 - learning_rate: 1.0000e-04
# Epoch 150/500
# 213/213 - 0s - 979us/step - loss: 0.0109 - val_loss: 0.0113 - learning_rate: 1.0000e-04
# Epoch 151/500
# 213/213 - 0s - 919us/step - loss: 0.0110 - val_loss: 0.0126 - learning_rate: 1.0000e-04
# Epoch 152/500
# 213/213 - 0s - 924us/step - loss: 0.0109 - val_loss: 0.0114 - learning_rate: 1.0000e-04
# Epoch 153/500
# 213/213 - 0s - 938us/step - loss: 0.0109 - val_loss: 0.0111 - learning_rate: 1.0000e-04
# Epoch 154/500
# 213/213 - 0s - 938us/step - loss: 0.0110 - val_loss: 0.0112 - learning_rate: 1.0000e-04
# Epoch 155/500
# 213/213 - 0s - 921us/step - loss: 0.0108 - val_loss: 0.0107 - learning_rate: 1.0000e-04
# Epoch 156/500
# 213/213 - 0s - 935us/step - loss: 0.0110 - val_loss: 0.0115 - learning_rate: 1.0000e-04
# Epoch 157/500
# 213/213 - 0s - 959us/step - loss: 0.0108 - val_loss: 0.0107 - learning_rate: 1.0000e-04
# Epoch 158/500
# 213/213 - 0s - 930us/step - loss: 0.0107 - val_loss: 0.0117 - learning_rate: 1.0000e-04
# Epoch 159/500
# 213/213 - 0s - 940us/step - loss: 0.0106 - val_loss: 0.0110 - learning_rate: 1.0000e-04
# Epoch 160/500
# 213/213 - 0s - 915us/step - loss: 0.0107 - val_loss: 0.0109 - learning_rate: 1.0000e-04
# Epoch 161/500
# 213/213 - 0s - 927us/step - loss: 0.0107 - val_loss: 0.0107 - learning_rate: 1.0000e-04
# Epoch 162/500
# 213/213 - 0s - 2ms/step - loss: 0.0107 - val_loss: 0.0116 - learning_rate: 1.0000e-04
# Epoch 163/500
# 213/213 - 0s - 1ms/step - loss: 0.0105 - val_loss: 0.0108 - learning_rate: 1.0000e-04
# Epoch 164/500
# 213/213 - 0s - 922us/step - loss: 0.0105 - val_loss: 0.0106 - learning_rate: 1.0000e-04
# Epoch 165/500
# 213/213 - 0s - 934us/step - loss: 0.0105 - val_loss: 0.0112 - learning_rate: 1.0000e-04
# Epoch 166/500
# 213/213 - 0s - 960us/step - loss: 0.0107 - val_loss: 0.0113 - learning_rate: 1.0000e-04
# Epoch 167/500
# 213/213 - 0s - 998us/step - loss: 0.0106 - val_loss: 0.0106 - learning_rate: 1.0000e-04
# Epoch 168/500
# 213/213 - 0s - 991us/step - loss: 0.0105 - val_loss: 0.0110 - learning_rate: 1.0000e-04
# Epoch 169/500
# 213/213 - 0s - 953us/step - loss: 0.0106 - val_loss: 0.0110 - learning_rate: 1.0000e-04
# Epoch 170/500
# 213/213 - 0s - 938us/step - loss: 0.0105 - val_loss: 0.0103 - learning_rate: 1.0000e-04
# Epoch 171/500
# 213/213 - 0s - 937us/step - loss: 0.0102 - val_loss: 0.0106 - learning_rate: 1.0000e-04
# Epoch 172/500
# 213/213 - 0s - 927us/step - loss: 0.0105 - val_loss: 0.0113 - learning_rate: 1.0000e-04
# Epoch 173/500
# 213/213 - 0s - 932us/step - loss: 0.0105 - val_loss: 0.0103 - learning_rate: 1.0000e-04
# Epoch 174/500
# 213/213 - 0s - 916us/step - loss: 0.0104 - val_loss: 0.0110 - learning_rate: 1.0000e-04
# Epoch 175/500
# 213/213 - 0s - 947us/step - loss: 0.0105 - val_loss: 0.0108 - learning_rate: 1.0000e-04
# Epoch 176/500
# 213/213 - 0s - 921us/step - loss: 0.0103 - val_loss: 0.0103 - learning_rate: 1.0000e-04
# Epoch 177/500
# 213/213 - 0s - 917us/step - loss: 0.0105 - val_loss: 0.0104 - learning_rate: 1.0000e-04
# Epoch 178/500
# 213/213 - 0s - 943us/step - loss: 0.0103 - val_loss: 0.0120 - learning_rate: 1.0000e-04
# Epoch 179/500
# 213/213 - 0s - 916us/step - loss: 0.0105 - val_loss: 0.0109 - learning_rate: 1.0000e-04
# Epoch 180/500
# 213/213 - 0s - 932us/step - loss: 0.0104 - val_loss: 0.0108 - learning_rate: 1.0000e-04
# Epoch 181/500
# 213/213 - 0s - 1ms/step - loss: 0.0103 - val_loss: 0.0102 - learning_rate: 1.0000e-04
# Epoch 182/500
# 213/213 - 0s - 1ms/step - loss: 0.0103 - val_loss: 0.0102 - learning_rate: 1.0000e-04
# Epoch 183/500
# 213/213 - 0s - 970us/step - loss: 0.0102 - val_loss: 0.0107 - learning_rate: 1.0000e-04
# Epoch 184/500
# 213/213 - 0s - 1ms/step - loss: 0.0102 - val_loss: 0.0102 - learning_rate: 1.0000e-04
# Epoch 185/500
# 213/213 - 0s - 1ms/step - loss: 0.0102 - val_loss: 0.0103 - learning_rate: 1.0000e-04
# Epoch 186/500
# 213/213 - 0s - 949us/step - loss: 0.0100 - val_loss: 0.0100 - learning_rate: 1.0000e-04
# Epoch 187/500
# 213/213 - 0s - 946us/step - loss: 0.0102 - val_loss: 0.0105 - learning_rate: 1.0000e-04
# Epoch 188/500
# 213/213 - 0s - 931us/step - loss: 0.0101 - val_loss: 0.0107 - learning_rate: 1.0000e-04
# Epoch 189/500
# 213/213 - 0s - 916us/step - loss: 0.0101 - val_loss: 0.0109 - learning_rate: 1.0000e-04
# Epoch 190/500
# 213/213 - 0s - 947us/step - loss: 0.0100 - val_loss: 0.0107 - learning_rate: 1.0000e-04
# Epoch 191/500
# 213/213 - 0s - 919us/step - loss: 0.0100 - val_loss: 0.0102 - learning_rate: 1.0000e-04
# Epoch 192/500
# 213/213 - 0s - 975us/step - loss: 0.0101 - val_loss: 0.0102 - learning_rate: 1.0000e-04
# Epoch 193/500
# 213/213 - 0s - 936us/step - loss: 0.0100 - val_loss: 0.0099 - learning_rate: 1.0000e-04
# Epoch 194/500
# 213/213 - 0s - 914us/step - loss: 0.0101 - val_loss: 0.0101 - learning_rate: 1.0000e-04
# Epoch 195/500
# 213/213 - 0s - 947us/step - loss: 0.0101 - val_loss: 0.0105 - learning_rate: 1.0000e-04
# Epoch 196/500
# 213/213 - 0s - 928us/step - loss: 0.0098 - val_loss: 0.0103 - learning_rate: 1.0000e-04
# Epoch 197/500
# 213/213 - 0s - 1ms/step - loss: 0.0102 - val_loss: 0.0104 - learning_rate: 1.0000e-04
# Epoch 198/500
# 213/213 - 0s - 1ms/step - loss: 0.0099 - val_loss: 0.0103 - learning_rate: 1.0000e-04
# Epoch 199/500
# 213/213 - 0s - 988us/step - loss: 0.0099 - val_loss: 0.0107 - learning_rate: 1.0000e-04
# Epoch 200/500
# 213/213 - 0s - 936us/step - loss: 0.0100 - val_loss: 0.0107 - learning_rate: 1.0000e-04
# Epoch 201/500
# 213/213 - 0s - 923us/step - loss: 0.0099 - val_loss: 0.0104 - learning_rate: 1.0000e-04
# Epoch 202/500
# 213/213 - 0s - 985us/step - loss: 0.0097 - val_loss: 0.0103 - learning_rate: 1.0000e-04
# Epoch 203/500
# 213/213 - 0s - 948us/step - loss: 0.0098 - val_loss: 0.0098 - learning_rate: 1.0000e-04
# Epoch 204/500
# 213/213 - 0s - 981us/step - loss: 0.0099 - val_loss: 0.0099 - learning_rate: 1.0000e-04
# Epoch 205/500
# 213/213 - 0s - 959us/step - loss: 0.0098 - val_loss: 0.0104 - learning_rate: 1.0000e-04
# Epoch 206/500
# 213/213 - 0s - 970us/step - loss: 0.0100 - val_loss: 0.0117 - learning_rate: 1.0000e-04
# Epoch 207/500
# 213/213 - 0s - 987us/step - loss: 0.0098 - val_loss: 0.0097 - learning_rate: 1.0000e-04
# Epoch 208/500
# 213/213 - 0s - 1ms/step - loss: 0.0097 - val_loss: 0.0096 - learning_rate: 1.0000e-04
# Epoch 209/500
# 213/213 - 0s - 1ms/step - loss: 0.0100 - val_loss: 0.0111 - learning_rate: 1.0000e-04
# Epoch 210/500
# 213/213 - 0s - 2ms/step - loss: 0.0097 - val_loss: 0.0106 - learning_rate: 1.0000e-04
# Epoch 211/500
# 213/213 - 0s - 1ms/step - loss: 0.0097 - val_loss: 0.0099 - learning_rate: 1.0000e-04
# Epoch 212/500
# 213/213 - 0s - 1ms/step - loss: 0.0099 - val_loss: 0.0118 - learning_rate: 1.0000e-04
# Epoch 213/500
# 213/213 - 0s - 956us/step - loss: 0.0098 - val_loss: 0.0103 - learning_rate: 1.0000e-04
# Epoch 214/500
# 213/213 - 0s - 971us/step - loss: 0.0096 - val_loss: 0.0100 - learning_rate: 1.0000e-04
# Epoch 215/500
# 213/213 - 0s - 951us/step - loss: 0.0097 - val_loss: 0.0097 - learning_rate: 1.0000e-04
# Epoch 216/500
# 213/213 - 0s - 984us/step - loss: 0.0096 - val_loss: 0.0098 - learning_rate: 1.0000e-04
# Epoch 217/500
# 213/213 - 0s - 970us/step - loss: 0.0097 - val_loss: 0.0110 - learning_rate: 1.0000e-04
# Epoch 218/500
# 213/213 - 0s - 973us/step - loss: 0.0096 - val_loss: 0.0100 - learning_rate: 1.0000e-04
# Epoch 219/500
# 213/213 - 0s - 937us/step - loss: 0.0097 - val_loss: 0.0102 - learning_rate: 1.0000e-04
# Epoch 220/500
# 213/213 - 0s - 937us/step - loss: 0.0096 - val_loss: 0.0095 - learning_rate: 1.0000e-04
# Epoch 221/500
# 213/213 - 0s - 963us/step - loss: 0.0095 - val_loss: 0.0095 - learning_rate: 1.0000e-04
# Epoch 222/500
# 213/213 - 0s - 963us/step - loss: 0.0096 - val_loss: 0.0097 - learning_rate: 1.0000e-04
# Epoch 223/500
# 213/213 - 0s - 943us/step - loss: 0.0096 - val_loss: 0.0110 - learning_rate: 1.0000e-04
# Epoch 224/500
# 213/213 - 0s - 932us/step - loss: 0.0096 - val_loss: 0.0098 - learning_rate: 1.0000e-04
# Epoch 225/500
# 213/213 - 0s - 981us/step - loss: 0.0095 - val_loss: 0.0099 - learning_rate: 1.0000e-04
# Epoch 226/500
# 213/213 - 0s - 1ms/step - loss: 0.0096 - val_loss: 0.0095 - learning_rate: 1.0000e-04
# Epoch 227/500
# 213/213 - 0s - 947us/step - loss: 0.0093 - val_loss: 0.0094 - learning_rate: 1.0000e-04
# Epoch 228/500
# 213/213 - 0s - 949us/step - loss: 0.0097 - val_loss: 0.0098 - learning_rate: 1.0000e-04
# Epoch 229/500
# 213/213 - 0s - 914us/step - loss: 0.0094 - val_loss: 0.0096 - learning_rate: 1.0000e-04
# Epoch 230/500
# 213/213 - 0s - 946us/step - loss: 0.0094 - val_loss: 0.0100 - learning_rate: 1.0000e-04
# Epoch 231/500
# 213/213 - 0s - 959us/step - loss: 0.0095 - val_loss: 0.0096 - learning_rate: 1.0000e-04
# Epoch 232/500
# 213/213 - 0s - 971us/step - loss: 0.0093 - val_loss: 0.0097 - learning_rate: 1.0000e-04
# Epoch 233/500
# 213/213 - 0s - 960us/step - loss: 0.0094 - val_loss: 0.0106 - learning_rate: 1.0000e-04
# Epoch 234/500
# 213/213 - 0s - 939us/step - loss: 0.0097 - val_loss: 0.0098 - learning_rate: 1.0000e-04
# Epoch 235/500
# 213/213 - 0s - 999us/step - loss: 0.0095 - val_loss: 0.0101 - learning_rate: 1.0000e-04
# Epoch 236/500
# 213/213 - 0s - 953us/step - loss: 0.0094 - val_loss: 0.0099 - learning_rate: 1.0000e-04
# Epoch 237/500
# 213/213 - 0s - 1ms/step - loss: 0.0093 - val_loss: 0.0100 - learning_rate: 1.0000e-04
# Epoch 238/500
# 213/213 - 0s - 957us/step - loss: 0.0095 - val_loss: 0.0095 - learning_rate: 1.0000e-04
# Epoch 239/500
# 213/213 - 0s - 942us/step - loss: 0.0091 - val_loss: 0.0093 - learning_rate: 1.0000e-04
# Epoch 240/500
# 213/213 - 0s - 972us/step - loss: 0.0093 - val_loss: 0.0095 - learning_rate: 1.0000e-04
# Epoch 241/500
# 213/213 - 0s - 962us/step - loss: 0.0093 - val_loss: 0.0094 - learning_rate: 1.0000e-04
# Epoch 242/500
# 213/213 - 0s - 1ms/step - loss: 0.0095 - val_loss: 0.0093 - learning_rate: 1.0000e-04
# Epoch 243/500
# 213/213 - 0s - 980us/step - loss: 0.0093 - val_loss: 0.0119 - learning_rate: 1.0000e-04
# Epoch 244/500
# 213/213 - 0s - 1ms/step - loss: 0.0093 - val_loss: 0.0094 - learning_rate: 1.0000e-04
# Epoch 245/500
# 213/213 - 0s - 1ms/step - loss: 0.0094 - val_loss: 0.0100 - learning_rate: 1.0000e-04
# Epoch 246/500
# 213/213 - 0s - 974us/step - loss: 0.0092 - val_loss: 0.0095 - learning_rate: 1.0000e-04
# Epoch 247/500
# 213/213 - 0s - 970us/step - loss: 0.0093 - val_loss: 0.0094 - learning_rate: 1.0000e-04
# Epoch 248/500
# 213/213 - 0s - 966us/step - loss: 0.0093 - val_loss: 0.0092 - learning_rate: 1.0000e-04
# Epoch 249/500
# 213/213 - 0s - 1ms/step - loss: 0.0092 - val_loss: 0.0114 - learning_rate: 1.0000e-04
# Epoch 250/500
# 213/213 - 0s - 922us/step - loss: 0.0094 - val_loss: 0.0092 - learning_rate: 1.0000e-04
# Epoch 251/500
# 213/213 - 0s - 915us/step - loss: 0.0092 - val_loss: 0.0093 - learning_rate: 1.0000e-04
# Epoch 252/500
# 213/213 - 0s - 923us/step - loss: 0.0091 - val_loss: 0.0093 - learning_rate: 1.0000e-04
# Epoch 253/500
# 213/213 - 0s - 921us/step - loss: 0.0092 - val_loss: 0.0096 - learning_rate: 1.0000e-04
# Epoch 254/500
# 213/213 - 0s - 926us/step - loss: 0.0092 - val_loss: 0.0108 - learning_rate: 1.0000e-04
# Epoch 255/500
# 213/213 - 0s - 919us/step - loss: 0.0092 - val_loss: 0.0097 - learning_rate: 1.0000e-04
# Epoch 256/500
# 213/213 - 0s - 931us/step - loss: 0.0092 - val_loss: 0.0100 - learning_rate: 1.0000e-04
# Epoch 257/500
# 213/213 - 0s - 940us/step - loss: 0.0090 - val_loss: 0.0090 - learning_rate: 1.0000e-04
# Epoch 258/500
# 213/213 - 0s - 929us/step - loss: 0.0092 - val_loss: 0.0096 - learning_rate: 1.0000e-04
# Epoch 259/500
# 213/213 - 0s - 911us/step - loss: 0.0091 - val_loss: 0.0108 - learning_rate: 1.0000e-04
# Epoch 260/500
# 213/213 - 0s - 931us/step - loss: 0.0091 - val_loss: 0.0093 - learning_rate: 1.0000e-04
# Epoch 261/500
# 213/213 - 0s - 931us/step - loss: 0.0093 - val_loss: 0.0107 - learning_rate: 1.0000e-04
# Epoch 262/500
# 213/213 - 0s - 931us/step - loss: 0.0090 - val_loss: 0.0113 - learning_rate: 1.0000e-04
# Epoch 263/500
# 213/213 - 0s - 916us/step - loss: 0.0093 - val_loss: 0.0095 - learning_rate: 1.0000e-04
# Epoch 264/500
# 213/213 - 0s - 908us/step - loss: 0.0089 - val_loss: 0.0096 - learning_rate: 1.0000e-04
# Epoch 265/500
# 213/213 - 0s - 945us/step - loss: 0.0089 - val_loss: 0.0097 - learning_rate: 1.0000e-04
# Epoch 266/500
# 213/213 - 0s - 920us/step - loss: 0.0091 - val_loss: 0.0094 - learning_rate: 1.0000e-04
# Epoch 267/500
# 213/213 - 0s - 934us/step - loss: 0.0089 - val_loss: 0.0099 - learning_rate: 1.0000e-04
# Epoch 268/500
# 213/213 - 0s - 953us/step - loss: 0.0091 - val_loss: 0.0091 - learning_rate: 1.0000e-04
# Epoch 269/500
# 213/213 - 0s - 953us/step - loss: 0.0089 - val_loss: 0.0093 - learning_rate: 1.0000e-04
# Epoch 270/500
# 213/213 - 0s - 954us/step - loss: 0.0091 - val_loss: 0.0091 - learning_rate: 1.0000e-04
# Epoch 271/500
# 213/213 - 0s - 948us/step - loss: 0.0092 - val_loss: 0.0091 - learning_rate: 1.0000e-04
# Epoch 272/500
# 213/213 - 0s - 943us/step - loss: 0.0090 - val_loss: 0.0114 - learning_rate: 1.0000e-04
# Epoch 273/500
# 213/213 - 0s - 912us/step - loss: 0.0091 - val_loss: 0.0092 - learning_rate: 1.0000e-04
# Epoch 274/500
# 213/213 - 0s - 936us/step - loss: 0.0088 - val_loss: 0.0091 - learning_rate: 1.0000e-04
# Epoch 275/500
# 213/213 - 0s - 972us/step - loss: 0.0091 - val_loss: 0.0093 - learning_rate: 1.0000e-04
# Epoch 276/500
# 213/213 - 0s - 922us/step - loss: 0.0089 - val_loss: 0.0101 - learning_rate: 1.0000e-04
# Epoch 277/500
# 213/213 - 0s - 932us/step - loss: 0.0090 - val_loss: 0.0090 - learning_rate: 1.0000e-04
# Epoch 278/500
# 213/213 - 0s - 944us/step - loss: 0.0090 - val_loss: 0.0100 - learning_rate: 1.0000e-04
# Epoch 279/500
# 213/213 - 0s - 931us/step - loss: 0.0089 - val_loss: 0.0087 - learning_rate: 1.0000e-04
# Epoch 280/500
# 213/213 - 0s - 978us/step - loss: 0.0090 - val_loss: 0.0098 - learning_rate: 1.0000e-04
# Epoch 281/500
# 213/213 - 0s - 1ms/step - loss: 0.0089 - val_loss: 0.0094 - learning_rate: 1.0000e-04
# Epoch 282/500
# 213/213 - 0s - 983us/step - loss: 0.0087 - val_loss: 0.0088 - learning_rate: 1.0000e-04
# Epoch 283/500
# 213/213 - 0s - 945us/step - loss: 0.0090 - val_loss: 0.0089 - learning_rate: 1.0000e-04
# Epoch 284/500
# 213/213 - 0s - 984us/step - loss: 0.0088 - val_loss: 0.0087 - learning_rate: 1.0000e-04
# Epoch 285/500
# 213/213 - 0s - 954us/step - loss: 0.0089 - val_loss: 0.0087 - learning_rate: 1.0000e-04
# Epoch 286/500
# 213/213 - 0s - 944us/step - loss: 0.0088 - val_loss: 0.0095 - learning_rate: 1.0000e-04
# Epoch 287/500
# 213/213 - 0s - 980us/step - loss: 0.0088 - val_loss: 0.0099 - learning_rate: 1.0000e-04
# Epoch 288/500
# 213/213 - 0s - 936us/step - loss: 0.0089 - val_loss: 0.0099 - learning_rate: 1.0000e-04
# Epoch 289/500
# 213/213 - 0s - 935us/step - loss: 0.0090 - val_loss: 0.0093 - learning_rate: 1.0000e-04
# Epoch 290/500
# 213/213 - 0s - 970us/step - loss: 0.0088 - val_loss: 0.0097 - learning_rate: 1.0000e-04
# Epoch 291/500
# 213/213 - 0s - 961us/step - loss: 0.0090 - val_loss: 0.0100 - learning_rate: 1.0000e-04
# Epoch 292/500
# 213/213 - 0s - 962us/step - loss: 0.0087 - val_loss: 0.0088 - learning_rate: 1.0000e-04
# Epoch 293/500
# 213/213 - 0s - 974us/step - loss: 0.0089 - val_loss: 0.0094 - learning_rate: 1.0000e-04
# Epoch 294/500
# 213/213 - 0s - 985us/step - loss: 0.0088 - val_loss: 0.0093 - learning_rate: 1.0000e-04
# Epoch 295/500
# 213/213 - 0s - 970us/step - loss: 0.0088 - val_loss: 0.0099 - learning_rate: 1.0000e-04
# Epoch 296/500
# 213/213 - 0s - 1ms/step - loss: 0.0088 - val_loss: 0.0091 - learning_rate: 1.0000e-04
# Epoch 297/500
# 213/213 - 0s - 969us/step - loss: 0.0087 - val_loss: 0.0088 - learning_rate: 1.0000e-04
# Epoch 298/500
# 213/213 - 0s - 950us/step - loss: 0.0090 - val_loss: 0.0090 - learning_rate: 1.0000e-04
# Epoch 299/500
# 213/213 - 0s - 952us/step - loss: 0.0086 - val_loss: 0.0088 - learning_rate: 1.0000e-04
# Epoch 300/500
# 213/213 - 0s - 946us/step - loss: 0.0089 - val_loss: 0.0098 - learning_rate: 1.0000e-04
# Epoch 301/500
# 213/213 - 0s - 1000us/step - loss: 0.0087 - val_loss: 0.0090 - learning_rate: 1.0000e-04
# Epoch 302/500
# 213/213 - 0s - 939us/step - loss: 0.0089 - val_loss: 0.0112 - learning_rate: 1.0000e-04
- val_loss: 0.0082 - learning_rate: 1.0000e-05
# Epoch 333/500
# 213/213 - 0s - 925us/step - loss: 0.0078 - val_loss: 0.0083 - learning_rate: 1.0000e-05
# Epoch 334/500
# 213/213 - 0s - 932us/step - loss: 0.0079 - val_loss: 0.0083 - learning_rate: 1.0000e-05
# Epoch 335/500
# 213/213 - 0s - 910us/step - loss: 0.0078 - val_loss: 0.0083 - learning_rate: 1.0000e-05
# Epoch 336/500
# 213/213 - 0s - 944us/step - loss: 0.0078 - val_loss: 0.0082 - learning_rate: 1.0000e-05
# Epoch 337/500
# 213/213 - 0s - 1ms/step - loss: 0.0079 - val_loss: 0.0082 - learning_rate: 1.0000e-05
# Epoch 338/500
# 213/213 - 0s - 957us/step - loss: 0.0079 - val_loss: 0.0082 - learning_rate: 1.0000e-05
# Epoch 339/500
# 213/213 - 0s - 952us/step - loss: 0.0078 - val_loss: 0.0082 - learning_rate: 1.0000e-05
# Epoch 340/500
# 213/213 - 0s - 944us/step - loss: 0.0078 - val_loss: 0.0083 - learning_rate: 1.0000e-05
# Epoch 341/500
# 213/213 - 0s - 944us/step - loss: 0.0077 - val_loss: 0.0082 - learning_rate: 1.0000e-06
# Epoch 342/500
# 213/213 - 0s - 978us/step - loss: 0.0077 - val_loss: 0.0082 - learning_rate: 1.0000e-06
# Epoch 343/500
# 213/213 - 0s - 947us/step - loss: 0.0077 - val_loss: 0.0081 - learning_rate: 1.0000e-06
# Epoch 344/500
# 213/213 - 0s - 951us/step - loss: 0.0077 - val_loss: 0.0082 - learning_rate: 1.0000e-06
# Epoch 345/500
# 213/213 - 0s - 1ms/step - loss: 0.0077 - val_loss: 0.0082 - learning_rate: 1.0000e-06
# Epoch 346/500
# 213/213 - 0s - 944us/step - loss: 0.0077 - val_loss: 0.0082 - learning_rate: 1.0000e-06
# Epoch 347/500
# 213/213 - 0s - 1ms/step - loss: 0.0077 - val_loss: 0.0082 - learning_rate: 1.0000e-06
# Epoch 348/500
# 213/213 - 0s - 963us/step - loss: 0.0077 - val_loss: 0.0081 - learning_rate: 1.0000e-06
# Epoch 349/500
# 213/213 - 0s - 974us/step - loss: 0.0077 - val_loss: 0.0081 - learning_rate: 1.0000e-06
# Epoch 350/500
# 213/213 - 0s - 946us/step - loss: 0.0077 - val_loss: 0.0081 - learning_rate: 1.0000e-06
# Epoch 351/500
# 213/213 - 0s - 957us/step - loss: 0.0077 - val_loss: 0.0082 - learning_rate: 1.0000e-06
# Epoch 352/500
# 213/213 - 0s - 943us/step - loss: 0.0077 - val_loss: 0.0082 - learning_rate: 1.0000e-06
# Epoch 353/500
# 213/213 - 0s - 943us/step - loss: 0.0077 - val_loss: 0.0081 - learning_rate: 1.0000e-06
# Epoch 354/500
# 213/213 - 0s - 960us/step - loss: 0.0077 - val_loss: 0.0081 - learning_rate: 1.0000e-06
# Epoch 355/500
# 213/213 - 0s - 946us/step - loss: 0.0077 - val_loss: 0.0081 - learning_rate: 1.0000e-06
# Epoch 356/500
# 213/213 - 0s - 962us/step - loss: 0.0077 - val_loss: 0.0082 - learning_rate: 1.0000e-06
# Epoch 357/500
# 213/213 - 0s - 953us/step - loss: 0.0077 - val_loss: 0.0081 - learning_rate: 1.0000e-06
# Epoch 358/500
# 213/213 - 0s - 932us/step - loss: 0.0077 - val_loss: 0.0081 - learning_rate: 1.0000e-06
# Epoch 359/500
# 213/213 - 0s - 975us/step - loss: 0.0077 - val_loss: 0.0081 - learning_rate: 1.0000e-06
# Epoch 360/500
# 213/213 - 0s - 949us/step - loss: 0.0077 - val_loss: 0.0082 - learning_rate: 1.0000e-06
# Epoch 361/500
# 213/213 - 0s - 986us/step - loss: 0.0077 - val_loss: 0.0082 - learning_rate: 1.0000e-06
# Epoch 362/500
# 213/213 - 0s - 963us/step - loss: 0.0077 - val_loss: 0.0082 - learning_rate: 1.0000e-06
# Epoch 363/500
# 213/213 - 0s - 1ms/step - loss: 0.0077 - val_loss: 0.0081 - learning_rate: 1.0000e-06
# Epoch 364/500
# 213/213 - 0s - 1ms/step - loss: 0.0077 - val_loss: 0.0081 - learning_rate: 1.0000e-06
# Epoch 365/500
# 213/213 - 0s - 973us/step - loss: 0.0077 - val_loss: 0.0081 - learning_rate: 1.0000e-06
# Epoch 366/500
# 213/213 - 0s - 974us/step - loss: 0.0077 - val_loss: 0.0081 - learning_rate: 1.0000e-06
# Epoch 367/500
# 213/213 - 0s - 946us/step - loss: 0.0077 - val_loss: 0.0081 - learning_rate: 1.0000e-06
# Epoch 368/500
# 213/213 - 0s - 965us/step - loss: 0.0077 - val_loss: 0.0081 - learning_rate: 1.0000e-06
# Epoch 369/500
# 213/213 - 0s - 971us/step - loss: 0.0077 - val_loss: 0.0081 - learning_rate: 1.0000e-06
# Epoch 370/500
# 213/213 - 0s - 943us/step - loss: 0.0077 - val_loss: 0.0081 - learning_rate: 1.0000e-06
# Epoch 371/500
# 213/213 - 0s - 972us/step - loss: 0.0077 - val_loss: 0.0081 - learning_rate: 1.0000e-06
# Epoch 372/500
# 213/213 - 0s - 952us/step - loss: 0.0077 - val_loss: 0.0081 - learning_rate: 1.0000e-06
# Epoch 373/500
# 213/213 - 0s - 949us/step - loss: 0.0077 - val_loss: 0.0081 - learning_rate: 1.0000e-06
# Epoch 374/500
# 213/213 - 0s - 953us/step - loss: 0.0077 - val_loss: 0.0081 - learning_rate: 1.0000e-06
# Epoch 375/500
# 213/213 - 0s - 976us/step - loss: 0.0077 - val_loss: 0.0081 - learning_rate: 1.0000e-06
# Epoch 376/500
# 213/213 - 0s - 963us/step - loss: 0.0077 - val_loss: 0.0081 - learning_rate: 1.0000e-06
# Epoch 377/500
# 213/213 - 0s - 948us/step - loss: 0.0077 - val_loss: 0.0081 - learning_rate: 1.0000e-06
# Epoch 378/500
# 213/213 - 0s - 950us/step - loss: 0.0077 - val_loss: 0.0081 - learning_rate: 1.0000e-06
# Epoch
/step - loss: 0.0077 - val_loss: 0.0081 - learning_rate: 1.0000e-08
# Epoch 478/500
# 213/213 - 0s - 953us/step - loss: 0.0077 - val_loss: 0.0081 - learning_rate: 1.0000e-08
# Epoch 479/500
# 213/213 - 0s - 940us/step - loss: 0.0077 - val_loss: 0.0081 - learning_rate: 1.0000e-08
# Epoch 480/500
# 213/213 - 0s - 953us/step - loss: 0.0077 - val_loss: 0.0081 - learning_rate: 1.0000e-08
# Epoch 481/500
# 213/213 - 0s - 990us/step - loss: 0.0077 - val_loss: 0.0081 - learning_rate: 1.0000e-08
# Epoch 482/500
# 213/213 - 0s - 956us/step - loss: 0.0077 - val_loss: 0.0081 - learning_rate: 1.0000e-08
# Epoch 483/500
# 213/213 - 0s - 958us/step - loss: 0.0077 - val_loss: 0.0081 - learning_rate: 1.0000e-08
# Epoch 484/500
# 213/213 - 0s - 932us/step - loss: 0.0077 - val_loss: 0.0081 - learning_rate: 1.0000e-08
# Epoch 485/500
# 213/213 - 0s - 988us/step - loss: 0.0077 - val_loss: 0.0081 - learning_rate: 1.0000e-08
# Epoch 486/500
# 213/213 - 0s - 924us/step - loss: 0.0077 - val_loss: 0.0081 - learning_rate: 1.0000e-08
# Epoch 487/500
# 213/213 - 0s - 967us/step - loss: 0.0077 - val_loss: 0.0081 - learning_rate: 1.0000e-08
# Epoch 488/500
# 213/213 - 0s - 954us/step - loss: 0.0077 - val_loss: 0.0081 - learning_rate: 1.0000e-08
# Epoch 489/500
# 213/213 - 0s - 945us/step - loss: 0.0077 - val_loss: 0.0081 - learning_rate: 1.0000e-08
# Epoch 490/500
# 213/213 - 0s - 941us/step - loss: 0.0077 - val_loss: 0.0081 - learning_rate: 1.0000e-08
# Epoch 491/500
# 213/213 - 0s - 961us/step - loss: 0.0077 - val_loss: 0.0081 - learning_rate: 1.0000e-08
# Epoch 492/500
# 213/213 - 0s - 966us/step - loss: 0.0077 - val_loss: 0.0081 - learning_rate: 1.0000e-08
# Epoch 493/500
# 213/213 - 0s - 950us/step - loss: 0.0077 - val_loss: 0.0081 - learning_rate: 1.0000e-08
# Epoch 494/500
# 213/213 - 0s - 949us/step - loss: 0.0077 - val_loss: 0.0081 - learning_rate: 1.0000e-08
# Epoch 495/500
# 213/213 - 0s - 945us/step - loss: 0.0077 - val_loss: 0.0081 - learning_rate: 1.0000e-08
# Epoch 496/500
# 213/213 - 0s - 937us/step - loss: 0.0077 - val_loss: 0.0081 - learning_rate: 1.0000e-08
# Epoch 497/500
# 213/213 - 0s - 1ms/step - loss: 0.0077 - val_loss: 0.0081 - learning_rate: 1.0000e-08
# Epoch 498/500
# 213/213 - 0s - 962us/step - loss: 0.0077 - val_loss: 0.0081 - learning_rate: 1.0000e-08
# Epoch 499/500
# 213/213 - 0s - 933us/step - loss: 0.0077 - val_loss: 0.0081 - learning_rate: 1.0000e-08
# Epoch 500/500
# 213/213 - 0s - 935us/step - loss: 0.0077 - val_loss: 0.0081 - learning_rate: 1.0000e-08
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 491us/step
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 392us/step
# /opt/anaconda3/envs/rtide_testing/lib/python3.11/site-packages/utide/_time_conversion.py:26: UserWarning: no explicit representation of timezones available for np.datetime64
#   date = date.astype("datetime64[ms]")

# %%
model.Visualize_Residuals(tides = True)

# %%
model.Visualize_Predictions()
# Out:
# Train Results
# r2: 0.996918370105285 MSE: 0.012126546280471023 MAE : 0.08670881830501947 MAPE : 0.18356265903493854

# %% [markdown]
# Note, visualizations can be generated at any time and will automatically include the train / test predictions where available.

# %%
model.Predict(surge_df[8000:])
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 708us/step
# /opt/anaconda3/envs/rtide_testing/lib/python3.11/site-packages/utide/_time_conversion.py:26: UserWarning: no explicit representation of timezones available for np.datetime64
#   date = date.astype("datetime64[ms]")

# %%
model.Visualize_Predictions()
# Out:
# Train Results
# r2: 0.996918370105285 MSE: 0.012126546280471023 MAE : 0.08670881830501947 MAPE : 0.18356265903493854
# Test Results
# r2: 0.9902913809317451 MSE: 0.04149828846949927 MAE : 0.1639758614353976 MAPE : 0.36445792449014786

# %% [markdown]
# Note that because we are using multivariate_lags for the surge signal, inspection of the SHAP values for the real-time surge will not paint the complete picture.

# %%
model.Shap_Analysis()
# Out:
# Computing SHAP values for forcing features (trend=linear)...
# Note: Time is held constant at median value (t_norm=-59.139) for this analysis.
# This shows how forcing features affect predictions independent of the secular trend.
#   0%|          | 0/757 [00:00<?, ?it/s]

# %% [markdown]
# Lets see what the true distribution looks like!

# %%
plt.scatter(surge[8000:], surge[8000:] + smooth_mults_test[8000:])

# %% [markdown]
# ### Comparing Derived Harmonics:

# %%
#### Helper Function for Computing
def constit_RMS(model_amplitudes, model_phases, HA_amplitudes, HA_phases, IRLS_amplitudes, IRLS_phases, actual_amplitudes, actual_phases, stat_type = 'Amplitude'):
  tvals = np.linspace(0,2*np.pi,1000)
  HA_errs = []
  RT_errs = []
  IRLS_errs = []
  for i,const in enumerate(constits):
    print(f"Computing {stat_type} errors")
    if stat_type == 'RMS':
      RTide_errors = np.sqrt(((model_amplitudes[i]*np.cos(tvals + (model_phases[i]*np.pi/180)) - actual_amplitudes[i]*np.cos(tvals + (actual_phases[i]*np.pi/180))))**2)
      HA_errors = np.sqrt(((HA_amplitudes[i]*np.cos(tvals + (HA_phases[i]*np.pi/180)) - actual_amplitudes[i]*np.cos(tvals + (actual_phases[i]*np.pi/180))))**2)
      IRLS_errors = np.sqrt(((IRLS_amplitudes[i]*np.cos(tvals + (IRLS_phases[i]*np.pi/180)) - actual_amplitudes[i]*np.cos(tvals + (actual_phases[i]*np.pi/180))))**2)
    elif stat_type == 'Amplitude':
      RTide_errors = abs(model_amplitudes[i] - actual_amplitudes[i])
      HA_errors = abs(HA_amplitudes[i] - actual_amplitudes[i])
      IRLS_errors = abs(IRLS_amplitudes[i] - actual_amplitudes[i])
    else:
      RTide_errors = abs(model_phases[i] - actual_phases[i])
      HA_errors = abs(HA_phases[i] - actual_phases[i])
      IRLS_errors = abs(IRLS_phases[i] - actual_phases[i])

    RT_errs.append(np.average(RTide_errors))
    HA_errs.append(np.average(HA_errors))
    IRLS_errs.append(np.average(IRLS_errors))
    print(f'{const}: RTide {round(np.average(RTide_errors),6)}')
    print(f'{const}: HA    {round(np.average(HA_errors),6)}')
    print(f'{const}: IRLS    {round(np.average(IRLS_errors),6)}')
  print(f"RSS RTide Error: {np.sqrt(np.sum(np.array(RT_errs)**2))}")
  print(f"RSS OLS Error: {np.sqrt(np.sum(np.array(HA_errs)**2))}")
  print(f"RSS IRLS Error: {np.sqrt(np.sum(np.array(IRLS_errs)**2))}")

def constit_RMS_latex(model_amplitudes, model_phases, HA_amplitudes, HA_phases, IRLS_amplitudes, IRLS_phases, actual_amplitudes, actual_phases, stat_type='Amplitude'):
    import numpy as np

    tvals = np.linspace(0, 2 * np.pi, 1000)
    HA_errs = []
    RT_errs = []
    IRLS_errs = []
    latex_rows = []

    for i, const in enumerate(constits):
        if stat_type == 'RMS':
            RTide_errors = np.sqrt(
                ((model_amplitudes[i] * np.cos(tvals + (model_phases[i] * np.pi / 180)) -
                  actual_amplitudes[i] * np.cos(tvals + (actual_phases[i] * np.pi / 180)))) ** 2)
            HA_errors = np.sqrt(
                ((HA_amplitudes[i] * np.cos(tvals + (HA_phases[i] * np.pi / 180)) -
                  actual_amplitudes[i] * np.cos(tvals + (actual_phases[i] * np.pi / 180)))) ** 2)
            IRLS_errors = np.sqrt(
                ((IRLS_amplitudes[i] * np.cos(tvals + (IRLS_phases[i] * np.pi / 180)) -
                  actual_amplitudes[i] * np.cos(tvals + (actual_phases[i] * np.pi / 180)))) ** 2)
        elif stat_type == 'Amplitude':
            RTide_errors = abs(model_amplitudes[i] - actual_amplitudes[i])
            HA_errors = abs(HA_amplitudes[i] - actual_amplitudes[i])
            IRLS_errors = abs(IRLS_amplitudes[i] - actual_amplitudes[i])
        else:
            RTide_errors = abs(model_phases[i] - actual_phases[i])
            HA_errors = abs(HA_phases[i] - actual_phases[i])
            IRLS_errors = abs(IRLS_phases[i] - actual_phases[i])

        RT_avg_error = np.average(RTide_errors)
        HA_avg_error = np.average(HA_errors)
        IRLS_avg_error = np.average(IRLS_errors)

        RT_errs.append(RT_avg_error)
        HA_errs.append(HA_avg_error)
        IRLS_errs.append(IRLS_avg_error)

        latex_rows.append(f"{const} & {RT_avg_error:.6f} & {HA_avg_error:.6f} & {IRLS_avg_error:.6f} \\\\")

    rss_RT_err = np.sqrt(np.sum(np.array(RT_errs) ** 2))
    rss_HA_err = np.sqrt(np.sum(np.array(HA_errs) ** 2))
    rss_IRLS_err = np.sqrt(np.sum(np.array(IRLS_errs) ** 2))

    latex_table = "\\begin{table}[h!]\n"
    latex_table += "\\centering\n"
    latex_table += "\\begin{tabular}{lccc}\n"
    latex_table += "\\toprule\n"
    latex_table += "Constituent & RTide Error & HA Error & IRLS Error \\\\\n"
    latex_table += "\\midrule\n"
    latex_table += "\n".join(latex_rows) + "\n"
    latex_table += "\\bottomrule\n"
    latex_table += "\\end{tabular}\n"
    latex_table += "\\caption{Errors for different constituents and methods}\n"
    latex_table += "\\end{table}\n"

    rss_latex_table = "\\begin{table}[h!]\n"
    rss_latex_table += "\\centering\n"
    rss_latex_table += "\\begin{tabular}{lc}\n"
    rss_latex_table += "\\toprule\n"
    rss_latex_table += "Method & RSS Error \\\\\n"
    rss_latex_table += "\\midrule\n"
    rss_latex_table += f"RTide & {rss_RT_err:.6f} \\\\\n"
    rss_latex_table += f"HA & {rss_HA_err:.6f} \\\\\n"
    rss_latex_table += f"IRLS & {rss_IRLS_err:.6f} \\\\\n"
    rss_latex_table += "\\bottomrule\n"
    rss_latex_table += "\\end{tabular}\n"
    rss_latex_table += "\\caption{Root Sum of Squares (RSS) Errors}\n"
    rss_latex_table += "\\end{table}\n"

    print(latex_table)
    print(rss_latex_table)

# %%
### Obtaining constituents from RTide
RTide_amplitudes = model.rtide_ha['A']
RTide_phases = model.rtide_ha['g']

HA_amplitudes = model.utide_ha['A']
HA_phases = model.utide_ha['g']


HA_IRLS_amplitudes = model.utide_irls['A']
HA_IRLS_phases = model.utide_irls['g']

### Printing results
constit_RMS_latex(RTide_amplitudes, RTide_phases, HA_amplitudes, HA_phases, HA_IRLS_amplitudes,HA_IRLS_phases, amplitudes, phases, stat_type = 'RMS')
# Out:
# \begin{table}[h!]
# \centering
# \begin{tabular}{lccc}
# \toprule
# Constituent & RTide Error & HA Error & IRLS Error \\
# \midrule
# M2 & 0.680092 & 0.666131 & 0.691740 \\
# N2 & 0.717271 & 0.735119 & 0.739582 \\
# S2 & 0.336283 & 0.335228 & 0.341604 \\
# L2 & 0.103911 & 0.134263 & 0.133374 \\
# K1 & 0.147433 & 0.147992 & 0.144953 \\
# NU2 & 0.135654 & 0.154522 & 0.146079 \\
# O1 & 0.098622 & 0.101995 & 0.100605 \\
# K2 & 0.120983 & 0.119095 & 0.123392 \\
# 2N2 & 0.078477 & 0.057002 & 0.075893 \\
# M4 & 0.054182 & 0.055079 & 0.055001 \\
# LDA2 & 0.044027 & 0.051834 & 0.052105 \\
# P1 & 0.065851 & 0.043483 & 0.034629 \\
# M6 & 0.055219 & 0.050840 & 0.050693 \\
# 2MN6 & 0.037866 & 0.011683 & 0.029481 \\
# SSA & 0.032016 & 0.031236 & 0.032694 \\
# MM & 0.026021 & 0.041487 & 0.020974 \\
# MN4 & 0.028631 & 0.026348 & 0.016616 \\
# 2MS6 & 0.022776 & 0.034752 & 0.021289 \\
# Q1 & 0.002490 & 0.022626 & 0.020755 \\
# MS4 & 0.022912 & 0.005702 & 0.008855 \\
# OQ2 & 0.015460 & 0.017781 & 0.011808 \\
# MF & 0.013300 & 0.022065 & 0.019732 \\
# EPS2 & 0.007444 & 0.006110 & 0.011357 \\
# NO1 & 0.005639 & 0.019287 & 0.014176 \\
# MU2 & 0.012996 & 0.016191 & 0.006745 \\
# MSF & 0.011276 & 0.010716 & 0.011178 \\
# MSN2 & 0.011982 & 0.012036 & 0.010553 \\
# MKS2 & 0.002166 & 0.012061 & 0.003815 \\
# MSM & 0.004610 & 0.011411 & 0.011294 \\
# TAU1 & 0.003224 & 0.010193 & 0.008927 \\
# CHI1 & 0.008047 & 0.008198 & 0.007880 \\
# 2MK6 & 0.006657 & 0.008522 & 0.004915 \\
# SIG1 & 0.009256 & 0.004776 & 0.004284 \\
# M8 & 0.002248 & 0.006362 & 0.006329 \\
# 2Q1 & 0.008527 & 0.004017 & 0.003308 \\
# ALP1 & 0.002639 & 0.006860 & 0.006135 \\
# J1 & 0.005193 & 0.006005 & 0.005572 \\
# MK3 & 0.006024 & 0.005792 & 0.000972 \\
# OO1 & 0.006317 & 0.004819 & 0.000942 \\
# RHO1 & 0.005721 & 0.003784 & 0.001692 \\
# MO3 & 0.005618 & 0.000955 & 0.004487 \\
# THE1 & 0.001326 & 0.001227 & 0.004778 \\
# ETA2 & 0.001741 & 0.002627 & 0.004378 \\
# MK4 & 0.002077 & 0.001920 & 0.001869 \\
# M3 & 0.001705 & 0.001809 & 0.000464 \\
# PHI1 & 0.003733 & 0.001568 & 0.002615 \\
# SO1 & 0.001604 & 0.001622 & 0.001487 \\
# MSK6 & 0.003267 & 0.000554 & 0.002398 \\
# 2SM6 & 0.001393 & 0.001802 & 0.000623 \\
# 2MK5 & 0.002070 & 0.001874 & 0.001308 \\
# 2SK5 & 0.002546 & 0.001210 & 0.000336 \\
# SO3 & 0.002205 & 0.001551 & 0.001269 \\
# SK4 & 0.001651 & 0.000609 & 0.001290 \\
# S4 & 0.001899 & 0.000349 & 0.000130 \\
# SN4 & 0.001363 & 0.001040 & 0.000549 \\
# UPS1 & 0.000878 & 0.000445 & 0.000225 \\
# SK3 & 0.000315 & 0.000383 & 0.000173 \\
# 3MK7 & 0.000163 & 0.000557 & 0.000400 \\
# BET1 & 0.000167 & 0.000228 & 0.000356 \\
# \bottomrule
# \end{tabular}
# \caption{Errors for different constituents and methods}
# \end{table}
#
# \begin{table}[h!]
# \centering
# \begin{tabular}{lc}
# \toprule
# Method & RSS Error \\
# \midrule
# RTide & 1.091010 \\
# HA & 1.098247 \\
# IRLS & 1.117241 \\
# \bottomrule
# \end{tabular}
# \caption{Root Sum of Squares (RSS) Errors}
# \end{table}
